# %%
from music import *

# %%
import youtube_dl

# %%
import pandas as pd
from youtubesearchpython import *
from os import path

# %%
import os

# %%
os.mkdir
# Out:
# <function posix.mkdir(path, mode=511, *, dir_fd=None)>

# %%
os.chdir("/Users/stephen/dabbles/youtube")

# %%
path.mkdir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-092f24923fe1> in <module>
# ----> 1 path.mkdir
#
# AttributeError: module 'posixpath' has no attribute 'mkdir'

# %%
tracks = dict(pd.read_csv("tracks.csv", index_col=0).T)

# %%
track = tracks[0]

# %%
track
# Out:
# track_name     No Church In The Wild
# artist_name                    JAY-Z
# album_name          Watch The Throne
# Name: 0, dtype: object

# %%
class Track:
    def __init__(self,
                 title,
                 artist,
                 album,
                 length=None):
        self.title = title
        self.artist = artist
        self.album = album
        self.length = length
        
    
    def create(dict_entry):
        return Track(dict_entry["track_name"],
                   dict_entry['artist_name'],
                   dict_entry['album_name'])
    
    def create_path(self):
        if not os.path.exists(os.path.join("Downloads", self.artist)):
            os.mkdir(os.path.join("Downloads", self.artist))
        if not os.path.exists(os.path.join("Downloads", self.artist, self.album)):
            os.mkdir(os.path.join("Downloads", self.artist, self.album))
        return os.path.join("Downloads", self.artist, self.album)
    
    def search(self):
        query = " ".join([self.title, self.artist, self.album]) 
        search = CustomSearch(query, VideoSortOrder.relevance, limit = 1)
        url = search.result()['result'][0]['link']
        return url
    
    
    def download(self):
        path = self.create_path()
        url = self.search()
        config = {
            'verbose': True,
            'outtmpl': f'downloads/{os.path.join(path, self.title)}.%(ext)s',
            'format': 'bestaudio/best',
            'postprocessors': [{
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'mp3',
                'preferredquality': '256',
            }]}
        
        with youtube_dl.YoutubeDL(config) as ydl:
            ydl.download([url])
            title = ydl.extract_info(url, download = False)["title"]
        print("Done")
        


class Artist:
    def __init__(self,
                 name):
        self.name = name

class Album:
    def __init__(self, title, artist):
        self.title = title
        self.artist = artist

# %%
help(youtube_dl.YoutubeDL)
# Out:
# Help on class YoutubeDL in module youtube_dl.YoutubeDL:
#
# class YoutubeDL(builtins.object)
#  |  YoutubeDL(params=None, auto_init=True)
#  |
#  |  YoutubeDL class.
#  |
#  |  YoutubeDL objects are the ones responsible of downloading the
#  |  actual video file and writing it to disk if the user has requested
#  |  it, among some other tasks. In most cases there should be one per
#  |  program. As, given a video URL, the downloader doesn't know how to
#  |  extract all the needed information, task that InfoExtractors do, it
#  |  has to pass the URL to one of them.
#  |
#  |  For this, YoutubeDL objects have a method that allows
#  |  InfoExtractors to be registered in a given order. When it is passed
#  |  a URL, the YoutubeDL object handles it to the first InfoExtractor it
#  |  finds that reports being able to handle it. The InfoExtractor extracts
#  |  all the information about the video or videos the URL refers to, and
# ...

# %%
pc = Track("cow", "polish", "the")

# %%
pc.download()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-60c24991ba4d> in <module>
# ----> 1 pc.download()
#
# <ipython-input-79-1860fa96b583> in download(self)
#      43             }]}
#      44
# ---> 45         with youtube_dl.YoutubeDL(config, verbose=True) as ydl:
#      46             ydl.download([url])
#      47             title = ydl.extract_info(url, download = False)["title"]
#
# TypeError: __init__() got an unexpected keyword argument 'verbose'

# %%
for key in tracks.keys():
    track = (Track.create(tracks[key]))

# %%
def create_folders(self):
    if not os.path.exists(os.path.join(os.getcwd(), track.artist)):
        os.mkdir(os.path.join(os.getcwd(), track.artist))
    if not os.path.exists(os.path.join(os.getcwd(), track.artist, track.album)):
        os.mkdir(os.path.join(os.getcwd(), track.artist, track.album))

# %%
create_folders(track)

# %%
keys = "track_name artist_name album_name".split(" ")

# %%
query = " ".join([tracks[0][key] for key in keys]) + " lyrics"
search = CustomSearch(query, VideoSortOrder.relevance, limit = 1)
url = search.result()['result'][0]['link']
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\_exceptions.py in map_exceptions(map)
#       7     try:
# ----> 8         yield
#       9     except Exception as exc:  # noqa: PIE786
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\backends\sync.py in start_tls(self, ssl_context, server_hostname, timeout)
#      56                 self.close()
# ---> 57                 raise exc
#      58         return SyncStream(sock)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\httpcore\backends\sync.py in start_tls(self, ssl_context, server_hostname, timeout)
# ...

# %%
print(query)
# Out:
# No Church In The Wild JAY-Z Watch The Throne lyrics
